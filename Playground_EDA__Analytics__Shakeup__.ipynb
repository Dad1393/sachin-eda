# %% [markdown]
# # **1. Data Collection**

# %% [markdown]
# **1.1 Importing File Formats**

# %%
import pandas as pd

# Importing CSV file
df = pd.read_csv('/content/ShakeupAnalysis.csv')

# %% [markdown]
# **1.21 Checking Data Types**

# %%
data_types = df.dtypes
print("Data Types:\n", data_types)
# Out:
# Data Types:
#  Private Rank             int64
# TeamId                   int64
# TeamName                object
# LastSubmissionDate      object
# Private Score          float64
# SubmissionCount          int64
# TeamMemberUserNames     object
# Public Score           float64
# Public Rank              int64
# Unnamed: 9             float64
# dtype: object

# %% [markdown]
# **1.22 Checking Duplicates**

# %%
duplicates = df.duplicated().sum()
print("Number of Duplicates:\n", duplicates)
# Out:
# Number of Duplicates:
#  0

# %% [markdown]
# # **2. Data Exploration**

# %% [markdown]
# **2.1 Understanding the Structure**

# %% [markdown]
# **2.11 View the First Few Rows**

# %%
df.head()
# Out:
#    Private Rank    TeamId             TeamName LastSubmissionDate  \
# 0             1  10820725  Tom Wright-Anderson   05-09-2023 09:02
# 1             2  10891496              rdebona   10-09-2023 21:40
# 2             3  10884347        Sando Breezez   10-09-2023 19:34
# 3             4  10883372         Maxime Perez   11-09-2023 09:42
# 4             5  10819987          Faysal Miah   31-08-2023 16:41
#
#    Private Score  SubmissionCount   TeamMemberUserNames  Public Score  \
# 0        1.00294               51  thomaswrightanderson       1.39531
# 1        1.00964                2               rdebona       1.41269
# 2        1.01086                1          sandobreezez       1.40443
# 3        1.01111                5           maximeperez       1.40479
# 4        1.01132                1     faysalmiah1721758       1.38375
#
#    Public Rank  Unnamed: 9
# 0          496         NaN
# 1          779         NaN
# 2          546         NaN
# 3          552         NaN
# 4          453         NaN

# %% [markdown]
# **2.12 View DataFrame Information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 955 entries, 0 to 954
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Private Rank         955 non-null    int64
#  1   TeamId               955 non-null    int64
#  2   TeamName             955 non-null    object
#  3   LastSubmissionDate   955 non-null    object
#  4   Private Score        955 non-null    float64
#  5   SubmissionCount      955 non-null    int64
#  6   TeamMemberUserNames  955 non-null    object
#  7   Public Score         955 non-null    float64
#  8   Public Rank          955 non-null    int64
#  9   Unnamed: 9           0 non-null      float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 74.7+ KB

# %% [markdown]
# **2.13 Summary Statistics**

# %%
df.describe()
# Out:
#        Private Rank        TeamId  Private Score  SubmissionCount  \
# count    955.000000  9.550000e+02     955.000000       955.000000
# mean     478.000000  1.083977e+07       1.222320        10.831414
# std      275.829053  2.086463e+04       1.285462        13.741849
# min        1.000000  1.081899e+07       1.002940         1.000000
# 25%      239.500000  1.082232e+07       1.026480         2.000000
# 50%      478.000000  1.083267e+07       1.048900         5.000000
# 75%      716.500000  1.085182e+07       1.077965        14.000000
# max      955.000000  1.089920e+07      30.206130       105.000000
#
#        Public Score  Public Rank  Unnamed: 9
# count    955.000000   955.000000         0.0
# mean       1.529410   478.000000         NaN
# std        1.255847   275.829053         NaN
# min        1.233360     1.000000         NaN
# 25%        1.328200   239.500000         NaN
# 50%        1.391510   478.000000         NaN
# 75%        1.407760   716.500000         NaN
# max       30.206450   955.000000         NaN

# %% [markdown]
# **2.14 View Column Names**

# %%
df.columns
# Out:
# Index(['Private Rank', 'TeamId', 'TeamName', 'LastSubmissionDate',
#        'Private Score', 'SubmissionCount', 'TeamMemberUserNames',
#        'Public Score', 'Public Rank', 'Unnamed: 9'],
#       dtype='object')

# %% [markdown]
# **2.15 Shape of the Data**

# %%
df.shape
# Out:
# (955, 10)

# %% [markdown]
# **2.16 View a Desired Sample of 5 Rows**

# %%
df.sample(5)
# Out:
#      Private Rank    TeamId              TeamName LastSubmissionDate  \
# 456           457  10846025               gondayo   30-08-2023 10:52
# 263           264  10832265               Rlxxnnn   08-09-2023 09:22
# 507           508  10826578            Seikou Ryo   23-08-2023 15:26
# 70             71  10822122              haruakif   22-08-2023 16:04
# 469           470  10864896  muhammad adeel badar   09-09-2023 05:33
#
#      Private Score  SubmissionCount TeamMemberUserNames  Public Score  \
# 456        1.04714                3        kanayamisato       1.31559
# 263        1.02648                2             rlxxnnn       1.35200
# 507        1.05008                1           seikouryo       1.37859
# 70         1.02393                3            haruakif       1.40402
# 469        1.04846                5         madeelbadar       1.41814
#
#      Public Rank  Unnamed: 9
# 456          189         NaN
# 263          312         NaN
# 507          417         NaN
# 70           542         NaN
# 469          793         NaN

# %% [markdown]
# **2.2 Missing Values**

# %% [markdown]
# **2.21 Identifying Missing Values**

# %%
print("Missing Values:\n", df.isnull().sum())
# Out:
# Missing Values:
#  Private Rank             0
# TeamId                   0
# TeamName                 0
# LastSubmissionDate       0
# Private Score            0
# SubmissionCount          0
# TeamMemberUserNames      0
# Public Score             0
# Public Rank              0
# Unnamed: 9             955
# dtype: int64

# %% [markdown]
# **2.22 Dropping Rows or Columns with Missing Values**

# %%
# Drop rows with any missing values
df_cleaned_rows = df.dropna()

# Drop columns with any missing values
df_cleaned_columns = df.dropna(axis=1)

# %% [markdown]
# # **3. Data Cleaning**

# %% [markdown]
# **3.1 Identifying Outliers using Z-Score**

# %%
from scipy import stats

# Calculate Z-scores of each value in the DataFrame
z_scores = stats.zscore(df.select_dtypes(include=['float64', 'int64']))

# Identify outliers (Z-score > 3 or < -3)
df_outliers = df[(z_scores > 3).any(axis=1) | (z_scores < -3).any(axis=1)]
print("Outliers:\n", df_outliers)
# Out:
# Outliers:
#       Private Rank    TeamId                    TeamName LastSubmissionDate  \
# 11             12  10823072              Hıdır BozkurtT   11-09-2023 19:28
# 31             32  10819189            Samvel Kocharyan   11-09-2023 04:44
# 308           309  10819817  Luck Processing Unit (TPU)   07-09-2023 06:50
# 314           315  10823617                  Jim Gruman   10-09-2023 20:33
# 363           364  10820096                 Oppenheimer   11-09-2023 06:25
# 373           374  10819137                       Lafoi   11-09-2023 04:23
# 387           388  10821168                   Dmitri K.   09-09-2023 22:42
# 398           399  10820005         KLYUSHNIK-Alexsandr   11-09-2023 11:51
# 463           464  10825670           PRASHANT SHUKLA91   11-09-2023 06:58
# 506           507  10819608               Itachi Uchiha   11-09-2023 09:57
# 621           622  10820110              Dr. Alvinleenh   10-09-2023 08:47
# 941        5.74054                1                       alexandrkhramov
# 942        5.74096                1                                ilsong
# 943        6.44205                3                       brijesh20119015
# 944        6.44333                2                           berkayeserr
# 945        7.38021                3                       armandoguzman92
# 946        8.16620                5                  ahmedgamalibrahimali
# 947        8.17955                1                         dylanmvanhorn
# 948        8.17955                1                         yutongguo0418
# 949        8.18005                6                           asahinomura
# 950        8.36628                1                               pakapro
# 951        8.40335                5                          rajatraj0502
# 952        8.57694                1                              johnkun1
# 953       14.33628                3                            yusufglcan
# 954       30.20613                1                          ziyuzhou0306
#
#      Public Score  Public Rank  Unnamed: 9
# 11        1.35305          315         NaN
# 31        1.35435          316         NaN
# 308       1.29887          138         NaN
# 314       1.41693          790         NaN
# 363       1.27506           90         NaN
# 373       1.23336            1         NaN
# 387       1.27060           71         NaN
# 398       1.34304          272         NaN
# 463       1.25568            8         NaN
# 506       1.26987           60         NaN
# 621       1.30695          164         NaN
# 631       1.25578            9         NaN
# 633       1.38547          461         NaN
# 673       1.26450           35         NaN
# 679       1.27242           80         NaN
# 733       1.37574          396         NaN
# 742       1.34866          301         NaN
# 753       1.31526          188         NaN
# 764       1.26562           40         NaN
# 786       1.40744          569         NaN
# 788       1.25763           17         NaN
# 807       1.24689            4         NaN
# 808       1.26462           36         NaN
# 811       1.25641           10         NaN
# 812       1.25543            7         NaN
# 928       1.96931          925         NaN
# 939       5.22445          940         NaN
# 940       5.44363          941         NaN
# 941       5.60355          942         NaN
# 942       5.89026          943         NaN
# 943       6.36345          944         NaN
# 944       6.56205          945         NaN
# 945       7.53012          946         NaN
# 946       8.30845          947         NaN
# 947       8.32176          948         NaN
# 948       8.32176          949         NaN
# 949       8.32227          950         NaN
# 950       8.50469          951         NaN
# 951       8.54578          952         NaN
# 952       8.71840          953         NaN
# 953      14.20983          954         NaN
# 954      30.20645          955         NaN

# %% [markdown]
# **3.2 Remove Outliers**

# %%
# Remove rows with outliers based on Z-score
df_no_outliers = df[(z_scores < 3).all(axis=1) & (z_scores > -3).all(axis=1)]
print("DataFrame without Outliers:\n", df_no_outliers)
# Out:
# DataFrame without Outliers:
#  Empty DataFrame
# Columns: [Private Rank, TeamId, TeamName, LastSubmissionDate, Private Score, SubmissionCount, TeamMemberUserNames, Public Score, Public Rank, Unnamed: 9]
# Index: []

# %% [markdown]
# # **In Depth Detailed Analysis**

# %% [markdown]
# **How do 'Private Score' and 'Public Score' relate to each other?**

# %%
import plotly.express as px

fig = px.scatter(df, x='Private Score', y='Public Score', title='Private Score vs Public Score')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c7025c90-e9aa-49d9-a190-1b026af277eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7025c90-e9aa-49d9-a190-1b026af277eb")) {                    Plotly.newPlot(                        "c7025c90-e9aa-49d9-a190-1b026af277eb",                        [{"hovertemplate":"Private Score=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1
# %% [markdown]
# **What is the relationship between 'SubmissionCount' and 'Public Score' for each team?**

# %%
fig = px.scatter(df, x='SubmissionCount', y='Public Score', color='TeamName',
                 title='Submission Count vs Public Score by Team Name',
                 labels={'SubmissionCount': 'Submission Count', 'Public Score': 'Public Score'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7e91b10f-6caa-4baf-9545-80e4778a895c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e91b10f-6caa-4baf-9545-80e4778a895c")) {                    Plotly.newPlot(                        "7e91b10f-6caa-4baf-9545-80e4778a895c",                        [{"hovertemplate":"TeamName=Tom Wright-Anderson\u003cbr\u003eSubmission Count=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tom Wright-Anderson","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Tom Wright-Anderson","orientation":"v","showlegend":true,"x":[51],"xaxis":"x","y":[1.39531],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=rdebona\u003cbr\u003eSubmission Count=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rdebona","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"rdebona","orientation":"v","showlegend":true,"x":[2],"xaxis":"x","y":[1.41269],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Sando Breezez\u003cbr\u003eSubmission Count=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sando Breezez","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Sando Breezez","orientation":"v","showlegend":true,"x":[1],"xaxis":"x","y":[1.40443],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Maxime Perez\u003cbr\u003eSubmission Count=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Maxime Perez","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Maxime Perez","orientation":"v","showlegend":true,"x":[5],"xaxis":"x","y":[1.40479],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Faysal Miah\u003cbr\u003eSubmission Count=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Faysal Miah","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Faysal Miah","orientation":"v","showlegend":true,"x":[1],"xaxis":"x","y":[1.38375],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Mayuri\u003cbr\u003eSubmission Count=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mayuri","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Mayuri","orientation":"v","showlegend":true,"x":[6],"xaxis":"x","y":[1.411],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Justin DeLarm\u003cbr\u003eSubmission Count=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Justin DeLarm","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Justin DeLarm","orientation":"v","showlegend":true,"x":[15],"xaxis":"x","y":[1.36225],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Prasanth naidu Karaka\u003cbr\u003eSubmission Count=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Prasanth naidu Karaka","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Prasanth naidu Karaka","orientation":"v","showlegend":true,"x":[17],"xaxis":"x","y":[1.37851],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=RLakshminarayanan\u003cbr\u003eSubmission Count=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RLakshminarayanan","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"RLakshminarayanan","orientation":"v","showlegend":true,"x":[9],"xaxis":"x","y":[1.41298],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=tluna\u003cbr\u003eSubmission Count=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","leg ...

# %% [markdown]
# **How do 'Private Score' and 'Public Score' compare within the dataset?**

# %%
fig = px.scatter(df, x='Private Score', y='Public Score', color='TeamName', trendline='ols',
                 title='Private Score vs Public Score with Trend Line',
                 labels={'Private Score': 'Private Score', 'Public Score': 'Public Score'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4d90934a-1463-4541-9b00-497b906a6842" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d90934a-1463-4541-9b00-497b906a6842")) {                    Plotly.newPlot(                        "4d90934a-1463-4541-9b00-497b906a6842",                        [{"hovertemplate":"TeamName=Tom Wright-Anderson\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tom Wright-Anderson","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Tom Wright-Anderson","orientation":"v","showlegend":true,"x":[1.00294],"xaxis":"x","y":[1.39531],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Tom Wright-Anderson\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tom Wright-Anderson","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Tom Wright-Anderson","showlegend":false,"xaxis":"x","yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=rdebona\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rdebona","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"rdebona","orientation":"v","showlegend":true,"x":[1.00964],"xaxis":"x","y":[1.41269],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=rdebona\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rdebona","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"rdebona","showlegend":false,"xaxis":"x","yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Sando Breezez\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sando Breezez","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Sando Breezez","orientation":"v","showlegend":true,"x":[1.01086],"xaxis":"x","y":[1.40443],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Sando Breezez\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sando Breezez","marker":{"color":"#00cc96","symbol":"circle"},"mode":"lines","name":"Sando Breezez","showlegend":false,"xaxis":"x","yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Maxime Perez\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Maxime Perez","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Maxime Perez","orientation":"v","showlegend":true,"x":[1.01111],"xaxis":"x","y":[1.40479],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Maxime Perez\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Maxime Perez","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"lines","name":"Maxime Perez","showlegend":false,"xaxis":"x","yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Faysal Miah\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Faysal Miah","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Faysal Miah","orientation":"v","showlegend":true,"x":[1.01132],"xaxis":"x","y":[1.38375],"yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Faysal Miah\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Faysal Miah","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"lines","name":"Faysal Miah","showlegend":false,"xaxis":"x","yaxis":"y","type":"scatter"},{"hovertemplate":"TeamName=Mayuri\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ePublic Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mayuri","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Mayuri","orientation":"v","showlegend":true,"x":[1.01245],"xaxis":"x","y":[1.411],"yaxis":" ...

# %% [markdown]
# **What are the top 10 teams by 'SubmissionCount'?**

# %%
top_teams = df.nlargest(10, 'SubmissionCount')
fig = px.bar(top_teams, x='SubmissionCount', y='TeamName', color='SubmissionCount',
             title='Top 10 Teams by Submission Count',
             labels={'SubmissionCount': 'Submission Count', 'TeamName': 'Team Name'},
             orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8655352a-876f-4dc7-bc18-163756e5b583" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8655352a-876f-4dc7-bc18-163756e5b583")) {                    Plotly.newPlot(                        "8655352a-876f-4dc7-bc18-163756e5b583",                        [{"alignmentgroup":"True","hovertemplate":"Submission Count=%{marker.color}\u003cbr\u003eTeam Name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[105,94,90,76,75,74,72,70,68,68],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[105,94,90,76,75,74,72,70,68,68],"xaxis":"x","y":["Georgios Nikolitsis","Asmaa Nasr","PRASHANT SHUKLA91","Itachi Uchiha","Mark Voitov","KLYUSHNIK-Alexsandr","Benedito Neto","Oppenheimer","Chun Fu","Prosotas dubiosa"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"colo ...

# %% [markdown]
# **What is the average 'Private Score' for each 'TeamName'?**

# %%
import plotly.express as px

average_private_score = df.groupby('TeamName')['Private Score'].mean().reset_index()
fig = px.bar(average_private_score, x='TeamName', y='Private Score', color='Private Score',
             title='Average Private Score by Team Name',
             labels={'TeamName': 'Team Name', 'Private Score': 'Average Private Score'})
fig.update_layout(xaxis_tickangle=-90, width=8000, height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6fd99640-2658-4e39-bcef-7b95d98985ab" class="plotly-graph-div" style="height:800px; width:8000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fd99640-2658-4e39-bcef-7b95d98985ab")) {                    Plotly.newPlot(                        "6fd99640-2658-4e39-bcef-7b95d98985ab",                        [{"alignmentgroup":"True","hovertemplate":"Team Name=%{x}\u003cbr\u003eAverage Private Score=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1.0772,1.02481,1.03408,1.13536,1.02198,1.06913,1.04959,1.02648,1.05462,1.08479,1.0223,1.05016,1.03181,1.03343,1.02648,1.01733,1.02648,1.02648,1.02648,1.02648,1.11879,1.05558,1.02794,1.02648,1.05091,1.17689,1.05268,1.02648,1.02648,8.1662,1.02648,1.02648,1.05792,1.0708,1.04529,1.05519,1.12378,1.04718,1.34514,1.03336,1.06751,1.05219,1.22215,1.0314,1.02648,1.02448,5.74054,1.05408,1.41022,1.04961,1.12675,1.04373,1.02481,1.05039,1.12066,1.07605,1.03618,1.08279,1.02648,1.02648,1.02648,1.02648,1.04349,1.02648,1.06064,1.37853,1.04989,1.02639,1.05149,1.06217,1.02417,1.0419,1.02648,1.04416,1.03411,1.12509,1.12166,1.06581,1.05605,1.02648,1.13555,1.05245,1.02577,1.11698,1.0263,1.04323,1.05664,1.14677,1.
# %% [markdown]
# **What is the distribution of 'SubmissionCount' across different 'TeamName'?**

# %%
total_submission_count = df.groupby('TeamName')['SubmissionCount'].sum().reset_index()
fig = px.bar(total_submission_count, x='TeamName', y='SubmissionCount', color='SubmissionCount',
             title='Total Submission Count by Team Name',
             labels={'TeamName': 'Team Name', 'SubmissionCount': 'Total Submission Count'})
fig.update_layout(xaxis_tickangle=-90, width=8000, height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b19dd5f0-be43-41a8-bf74-436a67b00570" class="plotly-graph-div" style="height:800px; width:8000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b19dd5f0-be43-41a8-bf74-436a67b00570")) {                    Plotly.newPlot(                        "b19dd5f0-be43-41a8-bf74-436a67b00570",                        [{"alignmentgroup":"True","hovertemplate":"Team Name=%{x}\u003cbr\u003eTotal Submission Count=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1,31,1,41,5,59,3,5,9,11,6,21,5,14,3,24,3,1,10,2,54,6,1,2,2,4,2,10,10,5,1,5,1,12,9,5,1,16,1,2,5,25,9,21,1,13,1,29,1,22,10,39,1,10,1,18,12,43,5,5,1,2,26,1,17,7,9,4,10,34,9,4,5,25,12,2,10,12,3,9,6,5,4,1,2,1,30,7,8,6,3,11,94,1,9,3,8,3,5,1,52,21,10,2,2,1,4,47,9,72,1,9,2,8,24,8,15,1,11,62,9,7,1,5,10,23,10,10,34,21,17,2,1,8,1,2,3,9,46,1,1,4,12,10,21,3,1,5,13,15,1,68,2,10,21,13,3,6,8,7,3,19,1,1,12,1,20,10,1,37,19,1,2,20,5,17,1,39,7,38,41,6,4,1,4,64,2,31,1,6,7,19,5,67,39,1,32,4,8,1,4,10,9,5,1,12,56,8,9,17,2,5,5,10,1,3,6,3,3,5,2,16,21,25,21,41,5,25,4,5,20,4,1,11,2,1,15,11,4,18,9,5,30,29,3,3,1,7,18,59,8,4,1,105,3,6,16,5,3,17,4,2,5,4,5,1,3,22,2,4,3,1,7,4,1,15,21,9,2,9,10,1,4,4,10,1,11,15,1,18,23,23,54,4,20,1,8,1,4,1,1,20,13,11,76,5,3,1,12,8,15,1,25,1,4,6,20,7,5,1,4,7,14,4,3,30,12,7,1,57,12,4,13,2,7,4,7,1,8,5,40,5,3,8,1,1,9,3,15,12,7,8,34,1,1,74,9,3,13,16,3,1,4,16,1,5,5,1,1,16,20,1,11,21,5,13,1,3,1,11,9,5,16,1,4,19,16,60,2,5,45,1,1,31,9,18,5,2,11,4,4,4,8,3,6,30,65,7,29,4,13,20,1,8,27,14,2,1,4,3,7,6,31,1,7,17,6,11,3,75,9,5,21,1,1,19,6,1,7,2,2,26,5,6,3,9,17,1,17,22,1,16,1,4,10,4,6,22,4,31,4,5,7,1,9,1,15,3,11,30,1,10,4,5,12,6,1,3,19,12,2,12,18,10,1,3,3,4,1,1,16,35,3,6,1,17,2,15,16,1,3,1,23,30,2,1,10,6,3,1,4,8,2,1,5,1,20,1,39,70,6,1,31,2,90,1,1,16,1,14,2,11,12,1,4,1,37,5,13,7,5,5,10,2,2,17,1,1,6,1,1,8,5,10,68,6,19,32,9,3,19,3,5,5,4,6,1,8,1,15,12,60,1,31,5,20,5,2,14,28,5,2,10,1,6,25,5,1,4,4,7,7,15,4,2,10,2,1,1,1,6,6,8,7,19,1,2,4,64,1,24,29,1,8,11,63,1,2,5,9,3,1,3,35,26,25,19,10,29,3,4,1,3,15,3,12,1,1,2,1,4,1,3,5,26,14,1,39,1,30,1,9,12,1,2,1,3,12,1,31,15,1,19,25,5,12,1,1,6,22,8,34,23,11,2,14,7,1,11,6,2,14,3,45,1,11,14,1,1,3,40,5,5,12,18,1,1,59,8,31,3,1,51,26,10,1,3,17,5,8,10,3,4,5,9,25,1,15,4,8,19,4,13,1,36,1,5,4,1,5,42,1,10,1,3,14,1,2,4,2,29,7,11,3,3,9,6,5,4,14,5,42,6,6,5,1,1,1,21,2,50,25,18,9,5,1,3,5,1,18,8,3,9,1,43,8,5,5,2,10,1,2,5,4,3,6,18,23,5,1,1,18,3,2,17,1,5,14,21,5,10,3,1,10,5,10,2,15,1,1,5,9,6,25,12,30,3,4,5,32,39,27,3,41,6,37,1,3,4,37,12,1,4,22,5,10,1,5,5,12,3,1,16,2,5,43,7,12,58,4,1,2,37,1,18,3,4,1,2,2,23,1,5,2,5,9,6,1,1,1,5,25,2,12,3,8,4,10,15,14,9,25,8,2,10,22,4,2,2,9,17,1,9,22,3,2,1,13,23,4,2,8,5,27,29,6,1,2,1,19,6,13,3,14,2,2,6,9,2,19,9,1,9,20,1,10,7,1,6,2,7,2,18,11,4,3,4,1,33,3,1,15,1,1,11,4,3,19,15,1,5,35,5,1,1],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[" Abdul Bazid"," Arindam Das 07","A.Hira","AC","AI@Work","AI_Explorer","ANIBAH","AYAHM BARISH","A_Smol_Bread","Aaradhya Badal","Aaron Alvarado Kristanto Julistiono","Aaryam Sharma","Abdullah Al Asif","Abhay Lejith","Abhishek Janapareddi","Abish Pius","AbishekPuri","Adam Griffith","AdamCage","Adarsh MM","Adel-in-Mil","Aditi Bansal","Aditya Gupta","Aditya Sharan","Aditya kishor","Aditya_Sarthak#2910","Ahmed Ali","Ahmed Ali Ali","Ahmed El-Taher","Ahmed Gamal ibrahim ali","Ahmed Mostafa","Ahmed_Yasser_911","AhmetDevran161","AiDeeSiS","AlalaKi","Alan Wu","Albert Antony","Alberto","Aleema PK","Alejandbel","Alex Dundore","Alex Kalitenko","Alex Zhu426","AlexHawkins","Alexander Goryachev","Alexander Kozachuk","Alexandr Khramov","Alexandre GAULT","Alexe","Alfa","Ali Alghaithi","Alich","Alili Aymen Abd Erraouf","Alpay Abbaszade","Alpiro Innovation Labs","Al ...

# %% [markdown]
# **How do the 'Public Score' and 'Private Score' averages compare for the top 5 teams with the highest 'SubmissionCount'?**

# %%
top_5_teams = df.nlargest(5, 'SubmissionCount')
average_scores = top_5_teams.groupby('TeamName').agg({'Private Score': 'mean', 'Public Score': 'mean'}).reset_index()
fig = px.bar(average_scores, x='TeamName', y=['Private Score', 'Public Score'],
             title='Average Private and Public Scores for Top 5 Teams by Submission Count',
             labels={'value': 'Average Score', 'variable': 'Score Type'})
fig.update_layout(xaxis_tickangle=-45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="11528226-4972-434f-91a8-abee730e7240" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11528226-4972-434f-91a8-abee730e7240")) {                    Plotly.newPlot(                        "11528226-4972-434f-91a8-abee730e7240",                        [{"alignmentgroup":"True","hovertemplate":"Score Type=Private Score\u003cbr\u003eTeamName=%{x}\u003cbr\u003eAverage Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Private Score","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Private Score","offsetgroup":"Private Score","orientation":"v","showlegend":true,"textposition":"auto","x":["Asmaa Nasr","Georgios Nikolitsis","Itachi Uchiha","Mark Voitov","PRASHANT SHUKLA91"],"xaxis":"x","y":[1.11814,1.09,1.05002,1.11967,1.04745],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Score Type=Public Score\u003cbr\u003eTeamName=%{x}\u003cbr\u003eAverage Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Public Score","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Public Score","offsetgroup":"Public Score","orientation":"v","showlegend":true,"textposition":"auto","x":["Asmaa Nasr","Georgios Nikolitsis","Itachi Uchiha","Mark Voitov","PRASHANT SHUKLA91"],"xaxis":"x","y":[1.24689,1.31526,1.26987,1.25543,1.25568],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777 ...

# %% [markdown]
# **What is the total number of submissions by 'TeamName' grouped by 'Private Score' range?**

# %%
import warnings
warnings.filterwarnings('ignore')
# Create a new column for Private Score ranges
df['Private Score Range'] = pd.cut(df['Private Score'], bins=[0, 50, 100, 150, 200, 250, 300],
                                   labels=['0-50', '51-100', '101-150', '151-200', '201-250', '251-300'])

submission_count_by_score_range = df.groupby('Private Score Range')['SubmissionCount'].sum().reset_index()
fig = px.bar(submission_count_by_score_range, x='Private Score Range', y='SubmissionCount', color='SubmissionCount',
             title='Total Submission Count by Private Score Range',
             labels={'Private Score Range': 'Private Score Range', 'SubmissionCount': 'Total Submission Count'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eaceebe1-c598-4c26-813f-83fe21024f92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eaceebe1-c598-4c26-813f-83fe21024f92")) {                    Plotly.newPlot(                        "eaceebe1-c598-4c26-813f-83fe21024f92",                        [{"alignmentgroup":"True","hovertemplate":"Private Score Range=%{x}\u003cbr\u003eTotal Submission Count=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[10344,0,0,0,0,0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["0-50","51-100","101-150","151-200","201-250","251-300"],"xaxis":"x","y":[10344,0,0,0,0,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"t ...

# %% [markdown]
# **What is the distribution of 'Private Score'?**

# %%
import plotly.express as px

fig = px.histogram(df, x='Private Score', nbins=30, color_discrete_sequence=['#1f77b4'],
                   title='Distribution of Private Score',
                   labels={'Private Score': 'Private Score'})
fig.update_layout(xaxis_title='Private Score', yaxis_title='Frequency')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="51e302ff-eb71-45f9-a0f8-8f4182709f12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51e302ff-eb71-45f9-a0f8-8f4182709f12")) {                    Plotly.newPlot(                        "51e302ff-eb71-45f9-a0f8-8f4182709f12",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Private Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1f77b4","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"x":[1.00294,1.00964,1.01086,1.01111,1.01132,1.01245,1.01252,1.01326,1.01409,1.0148,1.01492,1.01552,1.01566,1.01576,1.01616,1.01616,1.01619,1.01637,1.01646,1.01678,1.01681,1.01681,1.01699,1.01725,1.01733,1.0174,1.01768,1.0179,1.01843,1.01884,1.01885,1.01919,1.01929,1.0193,1.01954,1.01957,1.01972,1.01979,1.02013,1.02046,1.02056,1.02066,1.02075,1.02093,1.02128,1.02171,1.02179
"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888 ...

# %% [markdown]
# **How does the distribution of 'Private Score' vary by 'TeamName'?**

# %%
fig = px.histogram(df, x='Private Score', color='TeamName', nbins=30,
                   title='Distribution of Private Score by Team Name',
                   labels={'Private Score': 'Private Score', 'TeamName': 'Team Name'})
fig.update_layout(xaxis_title='Private Score', yaxis_title='Frequency')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="62e61138-7689-4837-a817-d6ba89775801" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62e61138-7689-4837-a817-d6ba89775801")) {                    Plotly.newPlot(                        "62e61138-7689-4837-a817-d6ba89775801",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Tom Wright-Anderson\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tom Wright-Anderson","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Tom Wright-Anderson","nbinsx":30,"offsetgroup":"Tom Wright-Anderson","orientation":"v","showlegend":true,"x":[1.00294],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=rdebona\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rdebona","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"rdebona","nbinsx":30,"offsetgroup":"rdebona","orientation":"v","showlegend":true,"x":[1.00964],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Sando Breezez\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sando Breezez","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Sando Breezez","nbinsx":30,"offsetgroup":"Sando Breezez","orientation":"v","showlegend":true,"x":[1.01086],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Maxime Perez\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Maxime Perez","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Maxime Perez","nbinsx":30,"offsetgroup":"Maxime Perez","orientation":"v","showlegend":true,"x":[1.01111],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Faysal Miah\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Faysal Miah","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Faysal Miah","nbinsx":30,"offsetgroup":"Faysal Miah","orientation":"v","showlegend":true,"x":[1.01132],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Mayuri\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mayuri","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Mayuri","nbinsx":30,"offsetgroup":"Mayuri","orientation":"v","showlegend":true,"x":[1.01245],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Justin DeLarm\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Justin DeLarm","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Justin DeLarm","nbinsx":30,"offsetgroup":"Justin DeLarm","orientation":"v","showlegend":true,"x":[1.01252],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Prasanth naidu Karaka\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Prasanth naidu Karaka","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Prasanth naidu Karaka","nbinsx":30,"offsetgroup":"Prasanth naidu Karaka","orientation":"v","showlegend":true,"x":[1.01326],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=RLakshminarayanan\u003cbr ...

# %% [markdown]
# **What is the distribution of 'Public Score' for the top 10 teams by 'SubmissionCount'?**

# %%
top_10_teams = df.nlargest(10, 'SubmissionCount')
fig = px.histogram(top_10_teams, x='Public Score', nbins=20, color='TeamName',
                   title='Distribution of Public Score for Top 10 Teams by Submission Count',
                   labels={'Public Score': 'Public Score', 'TeamName': 'Team Name'})
fig.update_layout(xaxis_title='Public Score', yaxis_title='Frequency')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2ee63eb9-b8f3-448a-a502-270ac7ffbdbc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ee63eb9-b8f3-448a-a502-270ac7ffbdbc")) {                    Plotly.newPlot(                        "2ee63eb9-b8f3-448a-a502-270ac7ffbdbc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Georgios Nikolitsis\u003cbr\u003ePublic Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Georgios Nikolitsis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Georgios Nikolitsis","nbinsx":20,"offsetgroup":"Georgios Nikolitsis","orientation":"v","showlegend":true,"x":[1.31526],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Asmaa Nasr\u003cbr\u003ePublic Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asmaa Nasr","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asmaa Nasr","nbinsx":20,"offsetgroup":"Asmaa Nasr","orientation":"v","showlegend":true,"x":[1.24689],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=PRASHANT SHUKLA91\u003cbr\u003ePublic Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PRASHANT SHUKLA91","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"PRASHANT SHUKLA91","nbinsx":20,"offsetgroup":"PRASHANT SHUKLA91","orientation":"v","showlegend":true,"x":[1.25568],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Itachi Uchiha\u003cbr\u003ePublic Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Itachi Uchiha","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Itachi Uchiha","nbinsx":20,"offsetgroup":"Itachi Uchiha","orientation":"v","showlegend":true,"x":[1.26987],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Mark Voitov\u003cbr\u003ePublic Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mark Voitov","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Mark Voitov","nbinsx":20,"offsetgroup":"Mark Voitov","orientation":"v","showlegend":true,"x":[1.25543],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=KLYUSHNIK-Alexsandr\u003cbr\u003ePublic Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KLYUSHNIK-Alexsandr","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"KLYUSHNIK-Alexsandr","nbinsx":20,"offsetgroup":"KLYUSHNIK-Alexsandr","orientation":"v","showlegend":true,"x":[1.34304],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Benedito Neto\u003cbr\u003ePublic Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Benedito Neto","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Benedito Neto","nbinsx":20,"offsetgroup":"Benedito Neto","orientation":"v","showlegend":true,"x":[1.40744],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Team Name=Oppenheimer\u003cbr\u003ePublic Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oppenheimer","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Oppenheimer","nbinsx":20,"offsetgroup":"Oppenheimer","orientation":"v","showlegend":true,"x":[1.27506],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate": ...

# %% [markdown]
# **What is the distribution of 'Private Score' for teams with high vs. low 'SubmissionCount'?**

# %%
df['SubmissionCategory'] = df['SubmissionCount'].apply(lambda x: 'High' if x > df['SubmissionCount'].median() else 'Low')

fig = px.histogram(df, x='Private Score', color='SubmissionCategory', nbins=30,
                   title='Distribution of Private Score by Submission Category',
                   labels={'Private Score': 'Private Score', 'SubmissionCategory': 'Submission Category'})
fig.update_layout(xaxis_title='Private Score', yaxis_title='Frequency')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="138a658e-1cf2-4972-9f32-bc098e775e04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("138a658e-1cf2-4972-9f32-bc098e775e04")) {                    Plotly.newPlot(                        "138a658e-1cf2-4972-9f32-bc098e775e04",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Submission Category=High\u003cbr\u003ePrivate Score=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"High","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"High","nbinsx":30,"offsetgroup":"High","orientation":"v","showlegend":true,"x":[1.00294,1.01245,1.01252,1.01326,1.01409,1.0148,1.01552,1.01566,1.01637,1.01646,1.01678,1.01681,1.01699,1.01725,1.01733,1.0174,1.01768,1.0179,1.01843,1.01885,1.01919,1.01929,1.0193,1.01957,1.02056,1.02066,1.02093,1.02171,1.02179,1.02185,1.02201,1.02204,1.02204,1.02206,1.02225,1.0223,1.02251,1.02257,1.02361,1.02371,1.02373,1.0239,1.02393,1.02417,1.02419,1.02431,1.02431,1.02436,1.02448,1.02448,1.02453,1.02475,1.02481,1.02481,1.02481,1.02482,1.02501,1.02509,1.02525,1.02527,1.02534,1.02534,1.02578,1.02624,1.02625,1.02631,1.02632,1.02634,1.02637,1.02638,1.02641,1.02642,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.
class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("393030a1-761c-426d-ba20-aedd4603a802")) {                    Plotly.newPlot(                        "393030a1-761c-426d-ba20-aedd4603a802",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Submission Count Category=%{label}\u003cbr\u003eNumber of Teams=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["0-10","11-20","21-30","31-40","41-50","51-60","61-70","71-80","81-90","91-100"],"legendgroup":"","name":"","showlegend":true,"values":[654,155,69,35,14,12,9,4,1,1],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatte ...

# %% [markdown]
# **What is the proportion of 'TeamName' with respect to 'Private Score'?**

# %%
# Summarize Private Score by TeamName
team_private_scores = df.groupby('TeamName')['Private Score'].sum().reset_index()
team_private_scores = team_private_scores.sort_values(by='Private Score', ascending=False).head(10)  # Top 10 Teams

fig = px.pie(team_private_scores, names='TeamName', values='Private Score',
             title='Proportion of Private Score by Team Name',
             labels={'TeamName': 'Team Name', 'Private Score': 'Private Score'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6e88058d-12ed-415f-9637-783a769fbe41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e88058d-12ed-415f-9637-783a769fbe41")) {                    Plotly.newPlot(                        "6e88058d-12ed-415f-9637-783a769fbe41",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Team Name=%{label}\u003cbr\u003ePrivate Score=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Kazemachi","Yusuf G\u00fclcan","John Kun1","Rajat Raj","Team +1","Asahi Nomura","Yutong Guo","Dylan M. Van Horn","Ahmed Gamal ibrahim ali","Jorge GUZMAN"],"legendgroup":"","name":"","showlegend":true,"values":[30.20613,14.33628,8.57694,8.40335,8.36628,8.18005,8.17955,8.17955,8.1662,7.38021],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}}," ...

# %% [markdown]
# **How is the distribution of 'Public Score' across different 'TeamName'?**

# %%
# Summarize Public Score by TeamName
team_public_scores = df.groupby('TeamName')['Public Score'].sum().reset_index()
team_public_scores = team_public_scores.sort_values(by='Public Score', ascending=False).head(10)  # Top 10 Teams

fig = px.pie(team_public_scores, names='TeamName', values='Public Score',
             title='Distribution of Public Score by Team Name',
             labels={'TeamName': 'Team Name', 'Public Score': 'Public Score'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e19a67dd-44b5-4d2f-8689-1dc221e6182a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e19a67dd-44b5-4d2f-8689-1dc221e6182a")) {                    Plotly.newPlot(                        "e19a67dd-44b5-4d2f-8689-1dc221e6182a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Team Name=%{label}\u003cbr\u003ePublic Score=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Kazemachi","Yusuf G\u00fclcan","John Kun1","Rajat Raj","Team +1","Asahi Nomura","Dylan M. Van Horn","Yutong Guo","Ahmed Gamal ibrahim ali","Jorge GUZMAN"],"legendgroup":"","name":"","showlegend":true,"values":[30.20645,14.20983,8.7184,8.54578,8.50469,8.32227,8.32176,8.32176,8.30845,7.53012],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"t ...

# %% [markdown]
# **What is the distribution of 'TeamName' in terms of 'Private Score'?**

# %%
# Summarize Private Score by TeamName
team_private_scores = df.groupby('TeamName')['Private Score'].sum().reset_index()
team_private_scores = team_private_scores.sort_values(by='Private Score', ascending=False).head(10)  # Top 10 Teams

fig = px.pie(team_private_scores, names='TeamName', values='Private Score',
             title='Distribution of Private Score Among Top 10 Teams',
             labels={'TeamName': 'Team Name', 'Private Score': 'Private Score'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1ae394a8-7cd7-4f17-a507-a555fbcb175d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ae394a8-7cd7-4f17-a507-a555fbcb175d")) {                    Plotly.newPlot(                        "1ae394a8-7cd7-4f17-a507-a555fbcb175d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Team Name=%{label}\u003cbr\u003ePrivate Score=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Kazemachi","Yusuf G\u00fclcan","John Kun1","Rajat Raj","Team +1","Asahi Nomura","Yutong Guo","Dylan M. Van Horn","Ahmed Gamal ibrahim ali","Jorge GUZMAN"],"legendgroup":"","name":"","showlegend":true,"values":[30.20613,14.33628,8.57694,8.40335,8.36628,8.18005,8.17955,8.17955,8.1662,7.38021],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}}," ...

# %% [markdown]
# **How is 'Public Score' distributed across different 'SubmissionCount' ranges?**

# %%
# Define submission count ranges
submission_ranges = [0, 20, 40, 60, 80, 100]

# Create a new column for Submission Count ranges
df['Submission Range'] = pd.cut(df['SubmissionCount'], bins=submission_ranges,
                                 labels=[f'{submission_ranges[i]}-{submission_ranges[i+1]}' for i in range(len(submission_ranges)-1)])

# Calculate average public score for each submission range
submission_range_scores = df.groupby('Submission Range')['Public Score'].mean().reset_index()

fig = px.pie(submission_range_scores, names='Submission Range', values='Public Score',
             title='Average Public Score Distribution by Submission Count Range',
             labels={'Submission Range': 'Submission Count Range', 'Public Score': 'Average Public Score'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1bbb18f2-68f4-4e0b-b0f4-3a77e9949e27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bbb18f2-68f4-4e0b-b0f4-3a77e9949e27")) {                    Plotly.newPlot(                        "1bbb18f2-68f4-4e0b-b0f4-3a77e9949e27",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Submission Count Range=%{label}\u003cbr\u003eAverage Public Score=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["0-20","20-40","40-60","60-80","80-100"],"legendgroup":"","name":"","showlegend":true,"values":[1.5630010135970334,1.350822403846154,1.3423142307692308,1.3011446153846153,1.251285],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"tic ...

# %% [markdown]
# **What is the distribution of 'SubmissionCount' across different 'TeamName'?**

# %%
# Summarize Submission Count by TeamName
team_submission_counts = df.groupby('TeamName')['SubmissionCount'].sum().reset_index()
team_submission_counts = team_submission_counts.sort_values(by='SubmissionCount', ascending=False).head(10)  # Top 10 Teams

fig = px.pie(team_submission_counts, names='TeamName', values='SubmissionCount',
             title='Distribution of Submission Count Among Top 10 Teams',
             labels={'TeamName': 'Team Name', 'SubmissionCount': 'Submission Count'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5038e028-4738-4f79-bf7b-210fdc628324" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5038e028-4738-4f79-bf7b-210fdc628324")) {                    Plotly.newPlot(                        "5038e028-4738-4f79-bf7b-210fdc628324",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Team Name=%{label}\u003cbr\u003eSubmission Count=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Georgios Nikolitsis","Asmaa Nasr","PRASHANT SHUKLA91","Itachi Uchiha","Mark Voitov","KLYUSHNIK-Alexsandr","Benedito Neto","Oppenheimer","Prosotas dubiosa","Chun Fu"],"legendgroup":"","name":"","showlegend":true,"values":[105,94,90,76,75,74,72,70,68,68],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type": ...

# %% [markdown]
# **How do 'Private Score', 'Public Score', and 'SubmissionCount' interact with each other?**

# %%
import plotly.express as px

fig = px.scatter_matrix(df, dimensions=['Private Score', 'Public Score', 'SubmissionCount'],
                       title='Pair Plot of Private Score, Public Score, and Submission Count',
                       labels={'Private Score': 'Private Score', 'Public Score': 'Public Score', 'SubmissionCount': 'Submission Count'})
fig.update_layout(xaxis_title='Variable', yaxis_title='Variable')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b7a3ff4f-abd5-4c09-96e4-39d22f3decfc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b
1.04323,1.04323,1.04323,1.04323,1.04323,1.04323,1.04323,1.04323,1.04323,1.04323,1.04323,1.04326,1.04326,1.04326,1.04332,1.04348,1.04349,1 ...

# %% [markdown]
# **How do 'Private Score' and 'Public Score' relate to each other across different 'SubmissionCount' ranges?**

# %%
import plotly.express as px

# Define submission count ranges
submission_ranges = [0, 20, 40, 60, 80, 100]

# Create a new column for Submission Count ranges
df['Submission Range'] = pd.cut(df['SubmissionCount'], bins=submission_ranges,
                                 labels=[f'{submission_ranges[i]}-{submission_ranges[i+1]}' for i in range(len(submission_ranges)-1)])

fig = px.scatter_matrix(df, dimensions=['Private Score', 'Public Score'],
                       color='Submission Range',
                       title='Pair Plot of Private Score and Public Score by Submission Count Range',
                       labels={'Private Score': 'Private Score', 'Public Score': 'Public Score', 'Submission Range': 'Submission Count Range'})
fig.update_layout(xaxis_title='Variable', yaxis_title='Variable')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2dac633f-0e1f-431f-ab92-bf0804346ca4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dac633f-0e1f-431f-ab92-bf0804346ca4")) {                    Plotly.newPlot(                        "2dac633f-0e1f-431f-ab92-bf0804346ca4",                        [{"dimensions":[{"axis":{"matches":true},"label":"Private Score","values":[1.00294,1.01552,1.02734,1.02978,1.03353,1.03823,1.04163,1.04375,1.04509,1.04926,1.06411,1.06464,1.06559,1.06913,1.07604,1.08025,1.08279,1.09368,1.09595,1.10211,1.11879,1.12092,1.1235,1.12361,1.13536,1.86596]},{"axis":{"matches":true},"label":"Public Score","values":[1.39531,1.35305,1.40567,1.41693,1.31703,1.23336,1.34946,1.37723,1.32015,1.3103,1.32973,1.3138,1.38547,1.2645,1.35247,1.37574,1.28092,1.26562,1.27506,1.25763,1.26462,1.25641,1.27677,1.2901,1.26353,1.96931]}],"hovertemplate":"Submission Count Range=40-60\u003cbr\u003e%{xaxis.title.text}=%{x}\u003cbr\u003e%{yaxis.title.text}=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"40-60","marker":{"color":"#636efa","symbol":"circle"},"name":"40-60","showlegend":true,"type":"splom"},{"dimensions":[{"axis":{"matches":true},"label":"Private Score","values":[1.00964,1.01086,1.01111,1.01132,1.01245,1.01252,1.01326,1.01409,1.0148,1.01492,1.01566,1.01576,1.01616,1.01616,1.01619,1.01637,1.01646,1.01678,1.01681,1.01699,1.01725,1.0174,1.01768,1.01843,1.01884,1.01885,1.01929,1.0193,1.01954,1.01957,1.01972,1.01979,1.02013,1.02046,1.02056,1.02066,1.02075,1.02093,1.02128,1.02171,1.02179,1.02179,1.02198,1.02201,1.02204,1.02204,1.02206,1.02225,1.0223,1.02251,1.02257,1.02278,1.02294,1.02321,1.02336,1.02347,1.02361,1.02363,1.02371,1.02373,1.0238,1.0239,1.02391,1.02393,1.02393,1.02417,1.02419,1.02424,1.02431,1.02448,1.02448,1.02451,1.02453,1.02465,1.02475,1.02481,1.02481,1.02481,1.02481,1.02519,1.02525,1.02528,1.02528,1.0253,1.02534,1.02553,1.02553,1.02576,1.02577,1.02583,1.02613,1.02624,1.02625,1.02625,1.0263,1.02631,1.02632,1.02634,1.02637,1.02638,1.02639,1.02639,1.02641,1.02642,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02648,1.02655,1.02656,1.02656,1.02669,1.02671,1.02672,1.02675,1.02687,1.02694,1.02738,1.02768,1.0277,1.0277,1.02784,1.02794,1.02813,1.02816,1.02831,1.02837,1.02851,1.02864,1.02865,1.02937,1.02937,1.02939,1.02943,1.02961,1.02995,1.02996,1.03005,1.03008,1.03011,1.03016,1.03017,1.03021,1.0304,1.03042,1.03059,1.03063,1.03073,1.03108,1.03125,1.03138,1.03181,1.03183,1.03183,1.03224,1.03285,1.03336, ...
